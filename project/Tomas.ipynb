# %%
import requests
import base64

CLIENT_ID = "client_marketdata_api"
CLIENT_SECRET = "client_marketdata_api"
SCOPE = "marketdata_api"
TOKEN_URL = "https://sts.nordpoolgroup.com/connect/token"

USERNAME = "s252876@student.dtu.dk"
PASSWORD = "gotqig-kyNja3-wynjiz"

credentials = f"{CLIENT_ID}:{CLIENT_SECRET}"
encoded = base64.b64encode(credentials.encode()).decode()

headers = {
    "Authorization": f"Basic {encoded}",
    "Content-Type": "application/x-www-form-urlencoded",
}

body = {
    "grant_type": "password",
    "scope": SCOPE,
    "username": USERNAME,
    "password": PASSWORD,
}

response = requests.post(TOKEN_URL, headers=headers, data=body)
print(response.text)  # check for errors
response.raise_for_status()

access_token = response.json()["access_token"]
print("Token retrieved successfully!")

body = {
    "grant_type": "password",
    "scope": SCOPE,
    "username": USERNAME,
    "password": PASSWORD,
}

# --- Request token ---
response = requests.post(TOKEN_URL, headers=headers, data=body)
response.raise_for_status()

token_data = response.json()
access_token = token_data["access_token"]
expires_in = token_data["expires_in"]  # seconds

print(f"Token: {access_token}")
print(f"Expires in: {expires_in}s")
# Out:
# {"access_token":"eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ik5CdWg4VFhkY0gzOHN0TzNaTjV3MmQtdU8zOCIsImtpZCI6Ik5CdWg4VFhkY0gzOHN0TzNaTjV3MmQtdU8zOCJ9.....VKISVv7c47-r6P8xv8GIjzyZ5kmhdd96TVZ86lMnzyI7yJsCC4hsXhdBsFKkMUx3Ui8Crfos_3vdRgAg9qGQ0at3oK9-R4hipPaUJoFRebZ1IGCmKosF_AD1OoS8hao2EUt_MIzbmTnNld9qnMIQNLKLtH4XK-utknqWPx2MDPom7KF8-iAIqE2j-sDEhLh0mbD3MGoRN8lqRxD0FwW4-S_27beyaYPJ5DDyNDO13onUoxAh5js5DbZZbq5wab65otis1gj0VPLRCVd-4SiCnhKTlD2aIo8Ku9_B4DDhx4iFBZFCz5K-5uh3qFXHGRBeZfrdIdazh2rkVk6v3ACz_QWCgWsrl0L2T0PacR7DGZLGX9WUN5Q0wR1EuKXgXsgFtA1vMBhyTh__Cya-gl6NOzJwOUJY_vCSDWgwgliIECrV5ji8bCZxWC92EPGlToz-QgqMJyVzRyhipCiAmd6fiy3UV3kDA89KzmW21ueNMKryDrVz5P9JHOKdS1rdr5gPbLgeWhAlOxqxxNkGat2nv5GoEw_ot8eqpkGmc8NF1fYbvrrZEpyx_SY9mvBMjvSN8R_xB8SF1CW9Bkix1B6hpjEdZ9Lg6gUbrDHXMAt7IPIl9nwG3v__WfZuv08pkeYy8J45b83DjSJXDKKv0LEPvWhZAgDgz8rFstg7Sr6jOME","expires_in":3600,"token_type":"Bearer"}
# Token retrieved successfully!
# Token: eyJ0eXAiOiJKV1QiLCJhbGciOiJSUzI1NiIsIng1dCI6Ik5CdWg4VFhkY0gzOHN0TzNaTjV3MmQtdU8zOCIsImtpZCI6Ik5CdWg4VFhkY0gzOHN0TzNaTjV3MmQtdU8zOCJ9.....VKISVv7c47-r6P8xv8GIjzyZ5kmhdd96TVZ86lMnzyI7yJsCC4hsXhdBsFKkMUx3Ui8Crfos_3vdRgAg9qGQ0at3oK9-R4hipPaUJoFRebZ1IGCmKosF_AD1OoS8hao2EUt_MIzbmTnNld9qnMIQNLKLtH4XK-utknqWPx2MDPom7KF8-iAIqE2j-sDEhLh0mbD3MGoRN8lqRxD0FwW4-S_27beyaYPJ5DDyNDO13onUoxAh5js5DbZZbq5wab65otis1gj0VPLRCVd-4SiCnhKTlD2aIo8Ku9_B4DDhx4iFBZFCz5K-5uh3qFXHGRBeZfrdIdazh2rkVk6v3ACz_QWCgWsrl0L2T0PacR7DGZLGX9WUN5Q0wR1EuKXgXsgFtA1vMBhyTh__Cya-gl6NOzJwOUJY_vCSDWgwgliIECrV5ji8bCZxWC92EPGlToz-QgqMJyVzRyhipCiAmd6fiy3UV3kDA89KzmW21ueNMKryDrVz5P9JHOKdS1rdr5gPbLgeWhAlOxqxxNkGat2nv5GoEw_ot8eqpkGmc8NF1fYbvrrZEpyx_SY9mvBMjvSN8R_xB8SF1CW9Bkix1B6hpjEdZ9Lg6gUbrDHXMAt7IPIl9nwG3v__WfZuv08pkeYy8J45b83DjSJXDKKv0LEPvWhZAgDgz8rFstg7Sr6jOME
# Expires in: 3600s

# %%
import pandas as pd

# --- Call API ---
params = {
    "market": "DayAhead",
    "areas": "EE,LT,LV,FI",
    "currency": "EUR",
    "date": "2024-01-01",
}

response = requests.get(
    "https://data-api.nordpoolgroup.com/api/v2/Auction/Prices/ByAreas",
    headers={"Authorization": f"Bearer {access_token}"},
    params=params,
)
response.raise_for_status()

# --- Parse into DataFrame ---
rows = []
for area_data in response.json():
    area = area_data["deliveryArea"]
    for price in area_data["prices"]:
        rows.append({
            "area": area,
            "deliveryStart": price["deliveryStart"],
            "deliveryEnd": price["deliveryEnd"],
            "price": price["price"],
        })

df = pd.DataFrame(rows)
df["deliveryStart"] = pd.to_datetime(df["deliveryStart"])
df["deliveryEnd"] = pd.to_datetime(df["deliveryEnd"])

print(df.head())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[2], line 16
#       4 params = {
#       5     "market": "DayAhead",
#       6     "areas": "EE,LT,LV,FI",
#       7     "currency": "EUR",
#       8     "date": "2024-01-01",
#       9 }
#      11 response = requests.get(
#      12     "https://data-api.nordpoolgroup.com/api/v2/Auction/Prices/ByAreas",
#      13     headers={"Authorization": f"Bearer {access_token}"},
#      14     params=params,
#      15 )
# ---> 16 response.raise_for_status()
#      18 # --- Parse into DataFrame ---
#      19 rows = []
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/requests/models.py:1024, in Response.raise_for_status(self)
#    1019     http_error_msg = (
#    1020         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1021     )
#    1023 if http_error_msg:
# -> 1024     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 403 Client Error: Forbidden for url: https://data-api.nordpoolgroup.com/api/v2/Auction/Prices/ByAreas?market=DayAhead&areas=EE%2CLT%2CLV%2CFI&currency=EUR&date=2024-01-01

# %%
response.text
# Out:
# 'Missing user management subscription'
